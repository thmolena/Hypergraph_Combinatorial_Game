# %%
# importing pandas as pd 
import pandas as pd 


import copy
def remove_a_step(starting_list_1,i):
    starting_list_2 = copy.deepcopy(starting_list_1)
    print("Remove " , starting_list_1[i])
    d["Remove"].append(starting_list_1[i])
    for j in range(len(starting_list_1)):
        a_letter = starting_list_1[j].find(starting_list_1[i])
        if a_letter != -1:
            starting_list_2.remove(starting_list_1[j])
    return starting_list_2



def get_vertices(starting_list):
    vertices = []
      
    for i in range(len(starting_list)):
        if len(starting_list[i]) == 1:
            vertices.append(starting_list[i])

    print("The list of the vertices: ",vertices)
    d["The list of the vertices"].append(vertices)
    return vertices


def get_hyperedges(starting_list):
    hyperedges = []
    
    for i in range(len(starting_list)):
        if len(starting_list[i]) != 1:
            hyperedges.append(starting_list[i])
    print("The list of the hyperedges: ",hyperedges)
    d["The list of the hyperedges"].append(hyperedges)
    return hyperedges


def oddly_uniform(number_of_vertices, number_of_hyperedges):
    if number_of_vertices %2 == 0 and number_of_hyperedges %2 == 0:
        nim_value = 0
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 == 0:
        nim_value = 1
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 != 0:
        nim_value = 2
    else:
        nim_value = 3
    return nim_value

def evenly_uniform(number_of_vertices, number_of_hyperedges):
    if number_of_vertices %2 == 0 and number_of_hyperedges %2 == 0:
        nim_value = 0
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 == 0:
        nim_value = 1
    elif number_of_vertices %2 == 0 and number_of_hyperedges %2 != 0:
        nim_value = 2
    else:
        nim_value = 3
    return nim_value

def find_nim(number_of_vertices, number_of_hyperedges, the_result_monotype):
    if the_result_monotype == "oddly":
        nim_value = oddly_uniform(number_of_vertices, number_of_hyperedges)
    elif the_result_monotype == "evenly":
        nim_value = evenly_uniform(number_of_vertices, number_of_hyperedges)
    return nim_value

def check_monotype(number_of_hyperedges,hyperedges):
    result_monotype = []
    for i in range(number_of_hyperedges):
        if len(hyperedges[i])%2 == 0:
           result_monotype.append("even")
        else:
           result_monotype.append("odd")
    if "even" not in result_monotype:
        the_result_monotype = "oddly"
    elif "odd" not in result_monotype:
        the_result_monotype = "evenly"
    else:
        the_result_monotype = "mixed"
    return the_result_monotype

def main():
    starting_number = input("Input the number of all vertices and hyperedges to start with? ")
    starting_number = int(starting_number)
    starting_list = []

    for i in range (starting_number):
        starting = input("Input a vertex or a hyperedge: ")
        starting_list.append(starting)

    starting_list_start =copy.deepcopy(starting_list) 
    global d 
    d = {"Level":[],"Starting with": [starting_list],"Remove":["None"],"The list of the vertices":[],"The list of the hyperedges":[],"Nim value":[]} 
    thy(starting_list_start,0)
       
    df = pd.DataFrame(d) 
    df.to_csv (r'C:\Users\Ron\Desktop\export_dataframe.csv', index = False, header=True)
    print(df)


def ahihi(starting_list_1,i):
    starting_list_2 = copy.deepcopy(starting_list_1)
    print("Starting with", starting_list_1)
    d["Starting with"].append(starting_list_1)
    starting_list_3 = remove_a_step(starting_list_2,i)
    print(starting_list_3)

            
    return starting_list_3

def ahaha(starting_list_1):
    vertices = get_vertices(starting_list_1)
    hyperedges = get_hyperedges(starting_list_1)

    if len(vertices) % 2 == 0:
        the_vertex = "even"
    else:
        the_vertex = "odd"

    if len(hyperedges) % 2 == 0:
        the_hyperedge = "even"
    else:
        the_hyperedge = "odd"
        
    
    print("There are ", the_vertex, " ( ", len(vertices), ")vertices")
    print("There are ", the_hyperedge, "( ", len(hyperedges), ") hyperedges")
    the_result_monotype = check_monotype(len(hyperedges),hyperedges)

    if the_result_monotype != "mixed":
        nim_value = find_nim(len(vertices), len(hyperedges), the_result_monotype)
        print("the nim_value is: ",nim_value)
    else:
        nim_value = 1000
        print("Cannot find the nim value yet since it is mixed.")
    return nim_value

def thy(starting_list_1,j=0):
    nim_value = ahaha(starting_list_1)
    d["Level"].append(j)
    d["Nim value"].append(nim_value)
   
    if nim_value == 1000:
        j+=1
        for i in range(len(starting_list_1)):
            print("")
            print("This is the ",j, "level")
       
            starting_list_3 = ahihi(starting_list_1,i)

            thy(starting_list_3,j)

main()
# Out:
# Input the number of all vertices and hyperedges to start with?  10
# Input a vertex or a hyperedge:  E
# Input a vertex or a hyperedge:  A
# Input a vertex or a hyperedge:  B
# Input a vertex or a hyperedge:  C
# Input a vertex or a hyperedge:  D
# Input a vertex or a hyperedge:  EAB
# Input a vertex or a hyperedge:  EBC
# Input a vertex or a hyperedge:  ECD
# Input a vertex or a hyperedge:  EDA
# Input a vertex or a hyperedge:  ABCD
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  5 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB', 'EBC']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  4 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'EDA']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ECD', 'EDA']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# the nim_value is:  2
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ECD', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  4 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'EDA']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB', 'EDA']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EDA']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EDA']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EDA']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  EDA
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ECD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ECD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ECD', 'EDA']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# the nim_value is:  2
#
# ...
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'ABCD']
# Remove  ECD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EBC', 'ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB', 'EBC']
# There are  even  (  4 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EBC']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EBC', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EBC']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  EBC
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'ABCD']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  E
# ['A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  A
# ['E', 'B', 'C', 'D']
# The list of the vertices:  ['E', 'B', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  B
# ['E', 'A', 'C', 'D']
# The list of the vertices:  ['E', 'A', 'C', 'D']
# The list of the hyperedges:  []
# There are  even  (  4 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  C
# ['E', 'A', 'B', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'D']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  D
# ['E', 'A', 'B', 'C', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C']
# The list of the hyperedges:  ['EAB']
# There are  even  (  4 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  EAB
# ['E', 'A', 'B', 'C', 'D', 'ABCD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['ABCD']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB']
# There are  odd  (  5 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EBC']
# There are  odd  (  5 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  2 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EBC', 'ECD']
# There are  odd  (  5 )vertices
# There are  odd (  3 ) hyperedges
# the nim_value is:  2
#
# This is the  1 level
# Starting with ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA', 'ABCD']
# Remove  ABCD
# ['E', 'A', 'B', 'C', 'D', 'EAB', 'EBC', 'ECD', 'EDA']
# The list of the vertices:  ['E', 'A', 'B', 'C', 'D']
# The list of the hyperedges:  ['EAB', 'EBC', 'ECD', 'EDA']
# There are  odd  (  5 )vertices
# There are  even (  4 ) hyperedges
# the nim_value is:  1
#      Level                              Starting with Remove  \
# 0        0  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]   None
# 1        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]      E
# 2        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]      A
# 3        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]      B
# 4        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]      C
# 5        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]      D
# 6        1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]    EAB
# 7        2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]      E
# 8        2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]      A
# 9        2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]      B
# 10       2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]      C
# 11       2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]      D
# 12       2       [E, A, B, C, D, EBC, ECD, EDA, ABCD]    EBC
# 13       3            [E, A, B, C, D, ECD, EDA, ABCD]      E
# 14       3            [E, A, B, C, D, ECD, EDA, ABCD]      A
# 15       3            [E, A, B, C, D, ECD, EDA, ABCD]      B
# 16       3            [E, A, B, C, D, ECD, EDA, ABCD]      C
# 17       3            [E, A, B, C, D, ECD, EDA, ABCD]      D
# 18       3            [E, A, B, C, D, ECD, EDA, ABCD]    ECD
# 19       4                 [E, A, B, C, D, EDA, ABCD]      E
# 20       4                 [E, A, B, C, D, EDA, ABCD]      A
# 21       4                 [E, A, B, C, D, EDA, ABCD]      B
# 22       4                 [E, A, B, C, D, EDA, ABCD]      C
# 23       4                 [E, A, B, C, D, EDA, ABCD]      D
# 24       4                 [E, A, B, C, D, EDA, ABCD]    EDA
# 25       4                 [E, A, B, C, D, EDA, ABCD]   ABCD
# 26       3            [E, A, B, C, D, ECD, EDA, ABCD]    EDA
# 27       4                 [E, A, B, C, D, ECD, ABCD]      E
# 28       4                 [E, A, B, C, D, ECD, ABCD]      A
# 29       4                 [E, A, B, C, D, ECD, ABCD]      B
# ..     ...                                        ...    ...
# 281      4                 [E, A, B, C, D, EAB, ABCD]      C
# 282      4                 [E, A, B, C, D, EAB, ABCD]      D
# 283      4                 [E, A, B, C, D, EAB, ABCD]    EAB
# 284      4                 [E, A, B, C, D, EAB, ABCD]   ABCD
# 285      3            [E, A, B, C, D, EAB, ECD, ABCD]   ABCD
# 286      2       [E, A, B, C, D, EAB, EBC, ECD, ABCD]    ECD
# 287      3            [E, A, B, C, D, EAB, EBC, ABCD]      E
# 288      3            [E, A, B, C, D, EAB, EBC, ABCD]      A
# 289      3            [E, A, B, C, D, EAB, EBC, ABCD]      B
# 290      3            [E, A, B, C, D, EAB, EBC, ABCD]      C
# 291      3            [E, A, B, C, D, EAB, EBC, ABCD]      D
# 292      3            [E, A, B, C, D, EAB, EBC, ABCD]    EAB
# 293      4                 [E, A, B, C, D, EBC, ABCD]      E
# 294      4                 [E, A, B, C, D, EBC, ABCD]      A
# 295      4                 [E, A, B, C, D, EBC, ABCD]      B
# 296      4                 [E, A, B, C, D, EBC, ABCD]      C
# 297      4                 [E, A, B, C, D, EBC, ABCD]      D
# 298      4                 [E, A, B, C, D, EBC, ABCD]    EBC
# 299      4                 [E, A, B, C, D, EBC, ABCD]   ABCD
# 300      3            [E, A, B, C, D, EAB, EBC, ABCD]    EBC
# 301      4                 [E, A, B, C, D, EAB, ABCD]      E
# 302      4                 [E, A, B, C, D, EAB, ABCD]      A
# 303      4                 [E, A, B, C, D, EAB, ABCD]      B
# 304      4                 [E, A, B, C, D, EAB, ABCD]      C
# 305      4                 [E, A, B, C, D, EAB, ABCD]      D
# 306      4                 [E, A, B, C, D, EAB, ABCD]    EAB
# 307      4                 [E, A, B, C, D, EAB, ABCD]   ABCD
# 308      3            [E, A, B, C, D, EAB, EBC, ABCD]   ABCD
# 309      2       [E, A, B, C, D, EAB, EBC, ECD, ABCD]   ABCD
# 310      1  [E, A, B, C, D, EAB, EBC, ECD, EDA, ABCD]   ABCD
#
#     The list of the vertices  The list of the hyperedges  Nim value
# 0            [E, A, B, C, D]  [EAB, EBC, ECD, EDA, ABCD]       1000
# 1               [A, B, C, D]                      [ABCD]          2
# 2               [E, B, C, D]                  [EBC, ECD]          0
# 3               [E, A, C, D]                  [ECD, EDA]          0
# 4               [E, A, B, D]                  [EAB, EDA]          0
# 5               [E, A, B, C]                  [EAB, EBC]          0
# 6            [E, A, B, C, D]       [EBC, ECD, EDA, ABCD]       1000
# 7               [A, B, C, D]                      [ABCD]          2
# 8               [E, B, C, D]                  [EBC, ECD]          0
# 9               [E, A, C, D]                  [ECD, EDA]          0
# 10              [E, A, B, D]                       [EDA]          3
# 11              [E, A, B, C]                       [EBC]          3
# 12           [E, A, B, C, D]            [ECD, EDA, ABCD]       1000
# 13              [A, B, C, D]                      [ABCD]          2
# 14              [E, B, C, D]                       [ECD]          3
# 15              [E, A, C, D]                  [ECD, EDA]          0
# 16              [E, A, B, D]                       [EDA]          3
# 17              [E, A, B, C]                          []          0
# 18           [E, A, B, C, D]                 [EDA, ABCD]       1000
# 19              [A, B, C, D]                      [ABCD]          2
# 20              [E, B, C, D]                          []          0
# 21              [E, A, C, D]                       [EDA]          3
# 22              [E, A, B, D]                       [EDA]          3
# 23              [E, A, B, C]                          []          0
# 24           [E, A, B, C, D]                      [ABCD]          3
# 25           [E, A, B, C, D]                       [EDA]          2
# 26           [E, A, B, C, D]                 [ECD, ABCD]       1000
# 27              [A, B, C, D]                      [ABCD]          2
# 28              [E, B, C, D]                       [ECD]          3
# 29              [E, A, C, D]                       [ECD]          3
# ..                       ...                         ...        ...
# 281             [E, A, B, D]                       [EAB]          3
# 282             [E, A, B, C]                       [EAB]          3
# 283          [E, A, B, C, D]                      [ABCD]          3
# 284          [E, A, B, C, D]                       [EAB]          2
# 285          [E, A, B, C, D]                  [EAB, ECD]          1
# 286          [E, A, B, C, D]            [EAB, EBC, ABCD]       1000
# 287             [A, B, C, D]                      [ABCD]          2
# 288             [E, B, C, D]                       [EBC]          3
# 289             [E, A, C, D]                          []          0
# 290             [E, A, B, D]                       [EAB]          3
# 291             [E, A, B, C]                  [EAB, EBC]          0
# 292          [E, A, B, C, D]                 [EBC, ABCD]       1000
# 293             [A, B, C, D]                      [ABCD]          2
# 294             [E, B, C, D]                       [EBC]          3
# 295             [E, A, C, D]                          []          0
# 296             [E, A, B, D]                          []          0
# 297             [E, A, B, C]                       [EBC]          3
# 298          [E, A, B, C, D]                      [ABCD]          3
# 299          [E, A, B, C, D]                       [EBC]          2
# 300          [E, A, B, C, D]                 [EAB, ABCD]       1000
# 301             [A, B, C, D]                      [ABCD]          2
# 302             [E, B, C, D]                          []          0
# 303             [E, A, C, D]                          []          0
# 304             [E, A, B, D]                       [EAB]          3
# 305             [E, A, B, C]                       [EAB]          3
# 306          [E, A, B, C, D]                      [ABCD]          3
# 307          [E, A, B, C, D]                       [EAB]          2
# 308          [E, A, B, C, D]                  [EAB, EBC]          1
# 309          [E, A, B, C, D]             [EAB, EBC, ECD]          2
# 310          [E, A, B, C, D]        [EAB, EBC, ECD, EDA]          1
#
# [311 rows x 6 columns]
