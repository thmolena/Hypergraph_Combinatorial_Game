# %%
# importing pandas as pd 
import pandas as pd 


import copy
def remove_a_step(starting_list_1,i):
    starting_list_2 = copy.deepcopy(starting_list_1)
    print("Remove " , starting_list_1[i])
    d["Remove"].append(starting_list_1[i])
    for j in range(len(starting_list_1)):
        a_letter = starting_list_1[j].find(starting_list_1[i])
        if a_letter != -1:
            starting_list_2.remove(starting_list_1[j])
    return starting_list_2



def get_vertices(starting_list):
    vertices = []
      
    for i in range(len(starting_list)):
        if len(starting_list[i]) == 1:
            vertices.append(starting_list[i])

    print("The list of the vertices: ",vertices)
    d["The list of the vertices"].append(vertices)
    return vertices


def get_hyperedges(starting_list):
    hyperedges = []
    
    for i in range(len(starting_list)):
        if len(starting_list[i]) != 1:
            hyperedges.append(starting_list[i])
    print("The list of the hyperedges: ",hyperedges)
    d["The list of the hyperedges"].append(hyperedges)
    return hyperedges


def oddly_uniform(number_of_vertices, number_of_hyperedges):
    if number_of_vertices %2 == 0 and number_of_hyperedges %2 == 0:
        nim_value = 0
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 == 0:
        nim_value = 1
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 != 0:
        nim_value = 2
    else:
        nim_value = 3
    return nim_value

def evenly_uniform(number_of_vertices, number_of_hyperedges):
    if number_of_vertices %2 == 0 and number_of_hyperedges %2 == 0:
        nim_value = 0
    elif number_of_vertices %2 != 0 and number_of_hyperedges %2 == 0:
        nim_value = 1
    elif number_of_vertices %2 == 0 and number_of_hyperedges %2 != 0:
        nim_value = 2
    else:
        nim_value = 3
    return nim_value

def find_nim(number_of_vertices, number_of_hyperedges, the_result_monotype):
    if the_result_monotype == "oddly":
        nim_value = oddly_uniform(number_of_vertices, number_of_hyperedges)
    elif the_result_monotype == "evenly":
        nim_value = evenly_uniform(number_of_vertices, number_of_hyperedges)
    return nim_value

def check_monotype(number_of_hyperedges,hyperedges):
    result_monotype = []
    for i in range(number_of_hyperedges):
        if len(hyperedges[i])%2 == 0:
           result_monotype.append("even")
        else:
           result_monotype.append("odd")
    if "even" not in result_monotype:
        the_result_monotype = "oddly"
    elif "odd" not in result_monotype:
        the_result_monotype = "evenly"
    else:
        the_result_monotype = "mixed"
    return the_result_monotype

def main():
    starting_number = input("Input the number of all vertices and hyperedges to start with? ")
    starting_number = int(starting_number)
    starting_list = []

    for i in range (starting_number):
        starting = input("Input a vertex or a hyperedge: ")
        starting_list.append(starting)

    starting_list_start =copy.deepcopy(starting_list) 
    global d 
    d = {"Level":[],"Starting with": [starting_list],"Remove":["None"],"The list of the vertices":[],"The list of the hyperedges":[],"Nim value":[]} 
    thy(starting_list_start,0)
       
    df = pd.DataFrame(d) 
    df.to_csv (r'Experiment.csv', index = False, header=True)
    print(df)


def ahihi(starting_list_1,i):
    starting_list_2 = copy.deepcopy(starting_list_1)
    print("Starting with", starting_list_1)
    d["Starting with"].append(starting_list_1)
    starting_list_3 = remove_a_step(starting_list_2,i)
    print(starting_list_3)

            
    return starting_list_3

def ahaha(starting_list_1):
    vertices = get_vertices(starting_list_1)
    hyperedges = get_hyperedges(starting_list_1)

    if len(vertices) % 2 == 0:
        the_vertex = "even"
    else:
        the_vertex = "odd"

    if len(hyperedges) % 2 == 0:
        the_hyperedge = "even"
    else:
        the_hyperedge = "odd"
        
    
    print("There are ", the_vertex, " ( ", len(vertices), ")vertices")
    print("There are ", the_hyperedge, "( ", len(hyperedges), ") hyperedges")
    the_result_monotype = check_monotype(len(hyperedges),hyperedges)

    if the_result_monotype != "mixed":
        nim_value = find_nim(len(vertices), len(hyperedges), the_result_monotype)
        print("the nim_value is: ",nim_value)
    else:
        nim_value = 1000
        print("Cannot find the nim value yet since it is mixed.")
    return nim_value

def thy(starting_list_1,j=0):
    nim_value = ahaha(starting_list_1)
    d["Level"].append(j)
    d["Nim value"].append(nim_value)
   
    if nim_value == 1000:
        j+=1
        for i in range(len(starting_list_1)):
            print("")
            print("This is the ",j, "level")
       
            starting_list_3 = ahihi(starting_list_1,i)

            thy(starting_list_3,j)

main()
# Out:
# Input the number of all vertices and hyperedges to start with?  16
# Input a vertex or a hyperedge:  B
# Input a vertex or a hyperedge:  C
# Input a vertex or a hyperedge:  D
# Input a vertex or a hyperedge:  E
# Input a vertex or a hyperedge:  F
# Input a vertex or a hyperedge:  G
# Input a vertex or a hyperedge:  H
# Input a vertex or a hyperedge:  I
# Input a vertex or a hyperedge:  J
# Input a vertex or a hyperedge:  K
# Input a vertex or a hyperedge:  L
# Input a vertex or a hyperedge:  GHIJKL
# Input a vertex or a hyperedge:  BCH
# Input a vertex or a hyperedge:  CDI
# Input a vertex or a hyperedge:  DEJ
# Input a vertex or a hyperedge:  EFK
# The list of the vertices:  ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'BCH', 'CDI', 'DEJ', 'EFK']
# There are  odd  (  11 )vertices
# There are  odd (  5 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  1 level
# Starting with ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'BCH', 'CDI', 'DEJ', 'EFK']
# Remove  B
# ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ', 'EFK']
# The list of the vertices:  ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'CDI', 'DEJ', 'EFK']
# There are  even  (  10 )vertices
# There are  even (  4 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  2 level
# Starting with ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ', 'EFK']
# Remove  C
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ', 'EFK']
# There are  odd  (  9 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  D
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  E
# ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  F
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  GHIJKL
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  DEJ
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  G
# ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  H
# ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  I
# ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  J
# ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  K
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  L
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  GHIJKL
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ', 'EFK']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# the nim_value is:  1
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  DEJ
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'EFK']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  D
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  EFK
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  F
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  GHIJKL
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  DEJ
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  GHIJKL
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  DEJ
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ', 'EFK']
# Remove  D
# ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'EFK']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  C
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'EFK']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['C', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['C', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['C', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['C', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['C', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['C', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ', 'EFK']
# Remove  E
# ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'CDI']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  C
# ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  D
# ['C', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  F
# ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'CDI']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  C
# ['D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  D
# ['C', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  G
# ['C', 'D', 'H', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  H
# ['C', 'D', 'G', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  I
# ['C', 'D', 'G', 'H', 'J', 'K', 'L']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  J
# ['C', 'D', 'G', 'H', 'I', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  K
# ['C', 'D', 'G', 'H', 'I', 'J', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  L
# ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  GHIJKL
# ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  CDI
# ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  G
# ['C', 'D', 'F', 'H', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  H
# ['C', 'D', 'F', 'G', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  I
# ['C', 'D', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  J
# ['C', 'D', 'F', 'G', 'H', 'I', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  K
# ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  L
# ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['CDI']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  GHIJKL
# ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'CDI']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['CDI']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# Remove  CDI
# ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  2 level
# Starting with ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ', 'EFK']
# Remove  F
# ['C', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ']
# The list of the vertices:  ['C', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'CDI', 'DEJ']
# There are  odd  (  9 )vertices
# There are  odd (  3 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  3 level
# Starting with ['C', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ']
# Remove  C
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  GHIJKL
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  4 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  DEJ
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ']
# Remove  D
# ['C', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['C', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  3 level
# Starting with ['C', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI', 'DEJ']
# Remove  E
# ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'CDI']
# The list of the vertices:  ['C', 'D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'CDI']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  4 level
# ...
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  7 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  7 level
# Starting with ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['B', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['B', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['B', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['B', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['B', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['B', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  E
# ['B', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  F
# ['B', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  G
# ['B', 'D', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  H
# ['B', 'D', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  I
# ['B', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  J
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  K
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  []
# There are  odd  (  9 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  L
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['EFK']
# There are  odd  (  9 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  GHIJKL
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'EFK']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['EFK']
# There are  even  (  10 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'EFK']
# Remove  EFK
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  10 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  4 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ', 'EFK']
# Remove  EFK
# ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  even  (  10 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  5 level
# Starting with ['B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  B
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  odd  (  9 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  F
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL', 'DEJ']
# There are  even  (  8 )vertices
# There are  even (  2 ) hyperedges
# Cannot find the nim value yet since it is mixed.
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  D
# ['E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  E
# ['D', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  odd  (  7 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  1
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  odd  (  7 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  GHIJKL
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  7 level
# Starting with ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  DEJ
# ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL']
# The list of the vertices:  ['D', 'E', 'G', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['GHIJKL']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  2
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  G
# ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'H', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  H
# ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'I', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  I
# ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'J', 'K', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  J
# ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'K', 'L']
# The list of the hyperedges:  []
# There are  even  (  8 )vertices
# There are  even (  0 ) hyperedges
# the nim_value is:  0
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  K
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'L']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
# Starting with ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'GHIJKL', 'DEJ']
# Remove  L
# ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'DEJ']
# The list of the vertices:  ['D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
# The list of the hyperedges:  ['DEJ']
# There are  even  (  8 )vertices
# There are  odd (  1 ) hyperedges
# the nim_value is:  3
#
# This is the  6 level
